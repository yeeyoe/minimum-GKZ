# %%
# This program compute the minimal GKZ vector associated to a point-configuration
# using function secondary_polytope() and minimize_constrained in Sagemath 
# input: point-configuration A
# output:

# %%
reset()

# %%
A = [[0,0], [1,0], [2,0], [1,1], [0,1]] # point-configuration

# mather example [4,0,0], [0,4,0], [0,0,4], [2,1,1], [1,2,1], [1,1,2]
# Naoto's five points [0,0], [1,0], [2,0], [1,1], [0,1]
# skew four points [0,0], [1,2], [2,1], [17,9]
# skew five points [1,0], [10,0], [18,7], [3,3], [0,1] 
Ap = PointConfiguration(A)
N = len(A) # number of points in A
n = len(A[0]) # dimension of A

# %%
print("number of points:", N)
# Out:
# number of points: 5

# %%
SP = Ap.secondary_polytope()  # the key function

# %%
V = SP.Vrepresentation() # vertices of SP

# %%
# find the vertex of SP with minimal norm, as the initial point. 
min_norm = float('inf')
min_index = 0
for i, v in enumerate(V):
    norm = sum(x**2 for x in v)
    if norm < min_norm:
        min_norm = norm
        min_index = i

# %%
# SP.Hrepresentation() # equations for the facets of SP

# %%
f = lambda x, i=i: sum(x[i]**2 for i in range(N)) # objection function: norm square

# %%
# extract the coefficients of the defining (in)equalities for SP
B = [eq[1:] for eq in SP.equations()]  # 提取 等式约束的x系数  Bx+b=0 
b = [eq[0] for eq in SP.equations()]  # 提取 等式约束的常数项
G = [ineq[1:] for ineq in SP.inequalities()]  # 提取 不等式约束的x系数  Gx+g>=0 
g = [ineq[0] for ineq in SP.inequalities()]  # 提取 不等式约束的常数项

# %%
# define the constraint conditions to call minimize_constrained()
cons = []
for i in range(len(B)):
    cons.append(lambda x, i=i: b[i]+sum(B[i][j] * x[j] for j in range(N)))
for i in range(len(B)):
    cons.append(lambda x, i=i: -b[i]-sum(B[i][j] * x[j] for j in range(N)))
for i in range(len(G)):
    cons.append(lambda x, i=i: g[i]+sum(G[i][j] * x[j] for j in range(N)))

# %%
# define the initial point in the minimizing process
init = list(SP.vertices()[4]) 

# use the minimal norm vertex as the initial point
# init = list(SP.vertices()[min_index])

# %%
# find the point on SP with minimal norm
mGKZ = minimize_constrained(f, cons, init)
# algorithm="SLSQP"  多面体的约束由线性等式和不等式组成
# algorithm="trust-constr" 高维问题或多面体有大量的约束（稀疏约束矩阵）

print("minimal GKZ vector is:", mGKZ)
# Out:
# minimal GKZ vector is: (1.666610726842023, 1.6667204673077283, 1.6666688058502488, 1.9999419209917737, 2.0000580790082263)

# %%
# compute the lower convex envelop of mGKZ
liftA = [a + [b] for a, b in zip(A, mGKZ)] # lifting A by mGKZ
liftQ = Polyhedron(liftA)
HLQ = liftQ.Hrepresentation()
lowHLQ = [ineq for ineq in HLQ if ineq[n+1] > 0] # select the lower facets
lowHLQ
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 3
#       1 # compute the lower convex envelop of mGKZ
#       2 liftA = [a + [b] for a, b in zip(A, mGKZ)] # lifting A by mGKZ
# ----> 3 liftQ = Polyhedron(liftA)
#       4 HLQ = liftQ.Hrepresentation()
#       5 lowHLQ = [ineq for ineq in HLQ if ineq[n+Integer(1)] > Integer(0)] # select the lower facets
#
# File /private/var/tmp/sage-10.5-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/misc/lazy_import.pyx:406, in sage.misc.lazy_import.LazyImport.__call__ (build/cythonized/sage/misc/lazy_import.c:6293)()
#     404         True
#     405     """
# --> 406     return self.get_object()(*args, **kwds)
#     407
#     408 def __repr__(self):
#
# File /private/var/tmp/sage-10.5-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/geometry/polyhedron/constructor.py:772, in Polyhedron(vertices, rays, lines, ieqs, eqns, ambient_dim, base_ring, minimize, verbose, backend, mutable)
#     770 if got_Vrep:
#     771     Vrep = [vertices, rays, lines]
# --> 772 return parent(Vrep, Hrep, convert=convert, verbose=verbose, mutable=mutable)
#
# File /private/var/tmp/sage-10.5-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/structure/parent.pyx:903, in sage.structure.parent.Parent.__call__ (build/cythonized/sage/structure/parent.c:12789)()
#     901         return mor._call_(x)
#     902     else:
# --> 903         return mor._call_with_args(x, args, kwds)
#     904
#     905 raise TypeError(_LazyString("No conversion defined from %s to %s", (R, self), {}))
#
# File /private/var/tmp/sage-10.5-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/structure/coerce_maps.pyx:183, in sage.structure.coerce_maps.DefaultConvertMap_unique._call_with_args (build/cythonized/sage/structure/coerce_maps.c:7578)()
#     181     print(type(C), C)
#     182     print(type(C._element_constructor), C._element_constructor)
# --> 183 raise
#     184
#     185
#
# File /private/var/tmp/sage-10.5-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/structure/coerce_maps.pyx:178, in sage.structure.coerce_maps.DefaultConvertMap_unique._call_with_args (build/cythonized/sage/structure/coerce_maps.c:7468)()
#     176             return C._element_constructor(x, *args)
#     177         else:
# --> 178             return C._element_constructor(x, *args, **kwds)
#     179 except Exception:
#     180     if print_warnings:
#
# File /private/var/tmp/sage-10.5-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/geometry/polyhedron/parent.py:682, in Polyhedra_base._element_constructor_(self, *args, **kwds)
#     680     if convert and Vrep:
#     681         Vrep = [convert_base_ring(_) for _ in Vrep]
# --> 682     return self.element_class(self, Vrep, Hrep, **kwds)
#     683 if nargs == 1 and isinstance(args[0], sage.geometry.abc.Polyhedron):
#     684     copy = kwds.pop('copy', args[0].parent() is not self)
#
# File /private/var/tmp/sage-10.5-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/geometry/polyhedron/backend_cdd_rdf.py:100, in Polyhedron_RDF_cdd.__init__(self, parent, Vrep, Hrep, **kwds)
#      86 def __init__(self, parent, Vrep, Hrep, **kwds):
#      87     """
#      88     The Python constructor.
#      89
#    (...)
#      98         sage: TestSuite(p).run()
#      99     """
# --> 100     Polyhedron_cdd.__init__(self, parent, Vrep, Hrep, **kwds)
#
# File /private/var/tmp/sage-10.5-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/geometry/polyhedron/base0.py:175, in Polyhedron_base0.__init__(self, parent, Vrep, Hrep, Vrep_minimal, Hrep_minimal, pref_rep, mutable, **kwds)
#     172     lines = tuple(lines)
#     174 if vertices or rays or lines:
# --> 175     self._init_from_Vrepresentation(vertices, rays, lines, **kwds)
#     176 else:
#     177     self._init_empty_polyhedron()
#
# File /private/var/tmp/sage-10.5-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/geometry/polyhedron/backend_cdd.py:69, in Polyhedron_cdd._init_from_Vrepresentation(self, vertices, rays, lines, verbose)
#      67 s = s[:s.index('end')+1]
#      68 s = '\n'.join(s)
# ---> 69 t = self._run_cdd(s, '--rep', verbose=verbose)
#      71 def parse(intro, data):
#      72     count = int(data[0][0])
#
# File /private/var/tmp/sage-10.5-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/geometry/polyhedron/backend_cdd.py:168, in Polyhedron_cdd._run_cdd(self, cdd_input_string, cmdline_arg, verbose)
#     165     print(err)
#     166 if 'Error:' in ans + err:
#     167     # cdd reports errors on stdout and misc information on stderr
# --> 168     raise ValueError(ans.strip())
#     169 return ans
#
# ValueError: *Error: Numerical inconsistency is found.  Use the GMP exact arithmetic.

# %%
 
F1 = liftQ.plot(axes=True)
F2 = point3d(liftA, color='red', size=100)
F3 = F1 + F2
F3.show()
# Out:
# Graphics3d Object

# %%
SP.show(axes=True) # show the secondary polytope SP
# Out:
# Graphics object consisting of 7 graphics primitives

# %%
Ae = [eq[0:] for eq in SP.equations()]
Ai = [ineq[0:] for ineq in SP.inequalities()]

# %%
Ae
# Out:
# [(-4, 0, 0, 0, 1, 1), (-2, 1, 0, -1, 0, 1), (-7, 2, 1, 0, 0, 1)]

# %%
Ai
# Out:
# [(-1, 1, 0, 0, 0, 0),
#  (3, 0, 0, 0, 0, -1),
#  (-3, 1, 0, 0, 0, 1),
#  (-1, 0, 0, 0, 0, 1),
#  (7, -2, 0, 0, 0, -1)]
